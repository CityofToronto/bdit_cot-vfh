# %% [markdown]
# # Create geojson file from list of PUDO coords
# See /home/test/Documents/PROJECTS/VFH/iPython_Notebooks/dv_pudo_profiles.ipynb for more info.
#
# ref: https://geoffboeing.com/2015/10/exporting-python-data-geojson/
# Huom: `with open(output_filename, 'wb') as output_file:` should be `'w'` not `'wb'`
#
# **Resources**
# geoJSON minifier: https://jsonformatter.org/json-minify

# %%
import sys
sys.executable
# Out:
# '/home/test/anaconda3/envs/vfh/bin/python'

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pandas.io.sql as pandasql
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker

from IPython.display import HTML, display
import datetime
import matplotlib.dates as mdates
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import os

from datetime import datetime

import json

# %% [markdown]
# # Functions

# %%
# https://geoffboeing.com/2015/10/exporting-python-data-geojson/
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = int(row[prop])
        geojson['features'].append(feature)
    return geojson

# %% [markdown]
# # GeoJSON properties for file

# %%
# Define the properties of the PUDO geojson file
prop = ['type','counts', 'overlap']

# %% [markdown]
# # Variables

# %%
ward=1
this_day = "Monday"
this_tod = "amPeak"

# %%
if ward == 1:
    test_id1 = 20232410   # 13454935
    test_id2 = 13453946
elif ward == 10:
    test_id1 = 13467106 # Adelaide and John
    test_id2 = 13466303

# %% [markdown]
# # Read PUDO data from csv file

# %%
fname = '../../../Documents/PROJECTS/VFH/COT_PAGE/INTERIM_DATA/FROM_PGADMIN/all_pudo_mon.csv'
# fname = '~/Documents/PROJECTS/BDITTO/VFH/DATA_STORY/DATA/from_pgAdmin/all_pudo_mon.csv'

df = pd.read_csv(fname)

print(df.shape)
df.head(5)
# Out:
# (494842, 14)
#        pickup_datetime     dropoff_datetime  pickup_ward2018  \
# 0  2018-09-03 00:00:00  2018-09-03 00:34:01             18.0
# 1  2018-09-03 00:00:00  2018-09-03 00:10:54             10.0
# 2  2018-09-03 00:00:00  2018-09-03 00:12:34             13.0
# 3  2018-09-03 00:00:00  2018-09-03 00:24:18             13.0
# 4  2018-09-03 00:00:00  2018-09-03 00:18:21              8.0
#
#    dropoff_ward2018  pickup_gc_intersection_id  dropoff_gc_intersection_id  \
# 0              10.0                   13447475                    13467654
# 1              13.0                   13467763                    13464030
# 2              10.0                   13464551                    13467763
# 3               3.0                   13465140                    13470547
# 4              13.0                   14044860                    14673305
#
#       dow timewindow                                        pickup_geom  \
# 0  Monday    nightII  0101000020E61000005BE2AF6670DA53C01D22DBEA93E2...
# 1  Monday    nightII  0101000020E610000051E519D30AD953C0C23B89A05BD2...
# 2  Monday    nightII  0101000020E6100000A342F6F3C6D753C0E8EE4CFEEDD4...
# 3  Monday    nightII  0101000020E6100000DF5023ED39D853C020ED2E3976D4...
# 4  Monday    nightII  0101000020E6100000A37FC1EFB8DC53C070C432B4FCDB...
#
#                                         dropoff_geom  lat_pickup  lon_pickup  \
# 0  0101000020E610000013E6CE309BD953C0938FE7777DD2...   43.770139  -79.413110
# 1  0101000020E610000079E6DB3E68D853C00F3AF08356D5...   43.643421  -79.391286
# 2  0101000020E610000051E519D30AD953C0C23B89A05BD2...   43.663513  -79.371518
# 3  0101000020E610000004410BFFE5E153C041B447898CCC...   43.659858  -79.378536
# 4  0101000020E61000008C84E11C68D853C062D98093A3D5...   43.718649  -79.448788
#
#    lat_dropoff  lon_dropoff
# 0    43.644454   -79.400097
# 1    43.666703   -79.381363
# 2    43.643421   -79.391286
# 3    43.598039   -79.529663
# 4    43.669054   -79.381355

# %%
list(df)
# Out:
# ['pickup_datetime',
#  'dropoff_datetime',
#  'pickup_ward2018',
#  'dropoff_ward2018',
#  'pickup_gc_intersection_id',
#  'dropoff_gc_intersection_id',
#  'dow',
#  'timewindow',
#  'pickup_geom',
#  'dropoff_geom',
#  'lat_pickup',
#  'lon_pickup',
#  'lat_dropoff',
#  'lon_dropoff']

# %%
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'pickup_gc_intersection_id'].count())
df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak')]
# Out:
# 12
#             pickup_datetime     dropoff_datetime  pickup_ward2018  \
# 38950   2018-09-03 07:00:00  2018-09-03 07:08:41              1.0
# 88959   2018-09-10 08:00:00  2018-09-10 08:12:39              1.0
# 97207   2018-09-17 07:00:00  2018-09-17 07:12:16              1.0
# 140853  2018-09-24 07:00:00  2018-09-24 07:21:00              1.0
# 140854  2018-09-24 07:00:00  2018-09-24 07:21:00              1.0
# 183409  2018-09-03 07:00:00  2018-09-03 07:15:17              1.0
# 240279  2018-09-17 08:00:00  2018-09-17 08:47:05              1.0
# 240582  2018-09-17 08:00:00  2018-09-17 08:22:07              1.0
# 246059  2018-09-17 07:00:00  2018-09-17 07:58:57              1.0
# 258887  2018-09-24 08:00:00  2018-09-24 08:11:44              1.0
# 265960  2018-09-24 08:00:00  2018-09-24 08:39:16              1.0
# 270435  2018-09-24 08:00:00  2018-09-24 08:05:17              1.0
#
#         dropoff_ward2018  pickup_gc_intersection_id  \
# 38950                1.0                   20232410
# 88959                1.0                   20232410
# 97207                1.0                   20232410
# 140853               1.0                   20232410
# 140854               1.0                   20232410
# 183409               3.0                   20232410
# 240279              21.0                   20232410
# 240582               3.0                   20232410
# 246059              21.0                   20232410
# 258887               1.0                   20232410
# 265960               8.0                   20232410
# 270435               1.0                   20232410
#
#         dropoff_gc_intersection_id     dow timewindow  \
# 38950                     30081632  Monday     amPeak
# 88959                     20232410  Monday     amPeak
# 97207                     13458127  Monday     amPeak
# 140853                    30081635  Monday     amPeak
# 140854                    30081635  Monday     amPeak
# 183409                    30071354  Monday     amPeak
# 240279                    13449905  Monday     amPeak
# 240582                    13470591  Monday     amPeak
# 246059                    20102020  Monday     amPeak
# 258887                    13460408  Monday     amPeak
# 265960                    13453819  Monday     amPeak
# 270435                    13452527  Monday     amPeak
#
#                                               pickup_geom  \
# 38950   0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 88959   0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 97207   0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 140853  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 140854  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 183409  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 240279  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 240582  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 246059  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 258887  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 265960  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
# 270435  0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...
#
#                                              dropoff_geom  lat_pickup  \
# 38950   0101000020E61000002D3BBACD78E353C00F64DF43F9DA...   43.728927
# 88959   0101000020E610000075DC3A49C4E653C09A9B9F7D4DDD...   43.728927
# 97207   0101000020E61000002B190A1CACE453C05F98C323EED9...   43.728927
# 140853  0101000020E6100000786CE01B3EE353C0C5D0B23AAEDA...   43.728927
# 140854  0101000020E6100000786CE01B3EE353C0C5D0B23AAEDA...   43.728927
# 183409  0101000020E6100000A29221642CE253C0679E157ED4CF...   43.728927
# 240279  0101000020E610000043B0776D19D153C0E5BAE7C823E0...   43.728927
# 240582  0101000020E6100000BD3611B95DE153C07D60FC7151CC...   43.728927
# 246059  0101000020E61000004EDEF8C1F6D053C03FE99A8262E0...   43.728927
# 258887  0101000020E61000003C54D9CB04E553C07379977E4ED8...   43.728927
# 265960  0101000020E6100000F81D23D6CBD953C0E681289539DD...   43.728927
# 270435  0101000020E61000007A43A507C1E553C0BC87F84591DE...   43.728927
#
#         lon_pickup  lat_dropoff  lon_dropoff
# 38950    -79.60573    43.710732   -79.554248
# 88959    -79.60573    43.728927   -79.605730
# 97207    -79.60573    43.702580   -79.573005
# 140853   -79.60573    43.708442   -79.550666
# 140854   -79.60573    43.708442   -79.550666
# 183409   -79.60573    43.623672   -79.533959
# 240279   -79.60573    43.751092   -79.267177
# 240582   -79.60573    43.596236   -79.521345
# 246059   -79.60573    43.753006   -79.265061
# 258887   -79.60573    43.689895   -79.578418
# 265960   -79.60573    43.728320   -79.403066
# 270435   -79.60573    43.738808   -79.589907

# %%
df.loc[(df['dropoff_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'dropoff_gc_intersection_id'].count()
# Out:
# 151

# %%
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['pickup_gc_intersection_id']==test_id1) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0), ['pickup_datetime','pickup_gc_intersection_id','dropoff_ward2018','dow','timewindow']]
# Out:
# 0
# Empty DataFrame
# Columns: [pickup_datetime, pickup_gc_intersection_id, dropoff_ward2018, dow, timewindow]
# Index: []

# %%
print(df.loc[(df['pickup_gc_intersection_id']==test_id2) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['pickup_gc_intersection_id']==test_id2) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0), ['pickup_datetime','pickup_gc_intersection_id','dropoff_ward2018','dow','timewindow']]
# Out:
# 0
# Empty DataFrame
# Columns: [pickup_datetime, pickup_gc_intersection_id, dropoff_ward2018, dow, timewindow]
# Index: []

# %%
thisid = 13453946

print(df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak'),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak')][['pickup_ward2018','dropoff_ward2018','dow','timewindow']]
# Out:
# 17
#         pickup_ward2018  dropoff_ward2018     dow timewindow
# 21103              10.0               1.0  Monday     amPeak
# 55108               1.0               1.0  Monday     amPeak
# 125591              7.0               1.0  Monday     amPeak
# 125592              1.0               1.0  Monday     amPeak
# 133786              5.0               1.0  Monday     amPeak
# 133882             15.0               1.0  Monday     amPeak
# 141570              7.0               1.0  Monday     amPeak
# 286280              3.0               1.0  Monday     amPeak
# 286295              1.0               1.0  Monday     amPeak
# 298822              8.0               1.0  Monday     amPeak
# 298823              8.0               1.0  Monday     amPeak
# 347543              8.0               1.0  Monday     amPeak
# 355990              1.0               1.0  Monday     amPeak
# 361525              9.0               1.0  Monday     amPeak
# 370813              8.0               1.0  Monday     amPeak
# 374278              7.0               1.0  Monday     amPeak
# 384418              7.0               1.0  Monday     amPeak

# %%
thisid = 13453946

print(df.loc[((df['pickup_gc_intersection_id']==thisid) | (df['dropoff_gc_intersection_id']==thisid)) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak'),
       'dropoff_gc_intersection_id'].count())

df.loc[((df['pickup_gc_intersection_id']==thisid) | (df['dropoff_gc_intersection_id']==thisid)) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak')][['pickup_ward2018','dropoff_ward2018','dow','timewindow']]
# Out:
# 19
#         pickup_ward2018  dropoff_ward2018     dow timewindow
# 21103              10.0               1.0  Monday     amPeak
# 55108               1.0               1.0  Monday     amPeak
# 82562               1.0               1.0  Monday     amPeak
# 125591              7.0               1.0  Monday     amPeak
# 125592              1.0               1.0  Monday     amPeak
# 133786              5.0               1.0  Monday     amPeak
# 133882             15.0               1.0  Monday     amPeak
# 141570              7.0               1.0  Monday     amPeak
# 238816              1.0              21.0  Monday     amPeak
# 286280              3.0               1.0  Monday     amPeak
# 286295              1.0               1.0  Monday     amPeak
# 298822              8.0               1.0  Monday     amPeak
# 298823              8.0               1.0  Monday     amPeak
# 347543              8.0               1.0  Monday     amPeak
# 355990              1.0               1.0  Monday     amPeak
# 361525              9.0               1.0  Monday     amPeak
# 370813              8.0               1.0  Monday     amPeak
# 374278              7.0               1.0  Monday     amPeak
# 384418              7.0               1.0  Monday     amPeak

# %% [markdown]
# # Housekeeping

# %% [markdown]
# ## 1. Round lat, lon to 4 decimal places

# %%
n=4 # number of decimals to round to

df['lat_pickup'] = df['lat_pickup'].round(decimals=n)
df['lon_pickup'] = df['lon_pickup'].round(decimals=n)

df['lat_dropoff'] = df['lat_dropoff'].round(decimals=n)
df['lon_dropoff'] = df['lon_dropoff'].round(decimals=n)

# %%
np.round(-79.60573035, decimals=n)
# Out:
# -79.6057

# %%
np.round(43.7289273, decimals=n)
# Out:
# 43.7289

# %% [markdown]
# ## 2. Filter out rows where neither pickup or dropoff wards are the ward of interest
# Make col `keep` = 1 for where pick-up or for drop-off wards are the ward of interest

# %%
# Assign a Pickup or Dropoff in column 'type'
df['keep'] = np.nan
df['latitude'] = np.nan
df['longitude'] = np.nan

df.loc[(df['pickup_ward2018']==ward) | (df['dropoff_ward2018']==ward), 'keep'] = 1

# %%
# Check
df['keep'].unique()
# Out:
# array([nan,  1.])

# %%
# Keep only rows where `keep` is not null
df = df[df['keep'].notnull()]

# %%
# Check
df['keep'].unique()
# Out:
# array([1.])

# %%
print(df.shape)
# Out:
# (18462, 17)

# %%
df.head(5)
# Out:
#          pickup_datetime     dropoff_datetime  pickup_ward2018  \
# 6    2018-09-03 00:00:00  2018-09-03 00:13:26              1.0
# 65   2018-09-03 00:00:00  2018-09-03 00:13:36              6.0
# 77   2018-09-03 00:00:00  2018-09-03 00:22:29              1.0
# 92   2018-09-03 01:00:00  2018-09-03 01:04:16              1.0
# 110  2018-09-03 00:00:00  2018-09-03 00:42:09             25.0
#
#      dropoff_ward2018  pickup_gc_intersection_id  dropoff_gc_intersection_id  \
# 6                 1.0                   30082386                    13460542
# 65                1.0                   30109966                    13451158
# 77                9.0                   13461025                    14047180
# 92                1.0                   13451763                    13450652
# 110               1.0                   13441921                    14075750
#
#         dow timewindow                                        pickup_geom  \
# 6    Monday    nightII  0101000020E61000002E8E37EAE2E653C01D39868BD2DC...
# 65   Monday    nightII  0101000020E6100000F094730106DF53C0346577E63DDF...
# 77   Monday    nightII  0101000020E6100000A9ABCBC11DE653C075770AAAE7D7...
# 92   Monday    nightII  0101000020E6100000716B477BC0E653C0A2CEA29838DF...
# 110  Monday    nightII  0101000020E61000008BC12B98A4CD53C04A9D99C3E2E8...
#
#                                           dropoff_geom  lat_pickup  \
# 6    0101000020E61000001223231E8BE653C012195BAA40D8...     43.7252
# 65   0101000020E61000002595DD571BE553C04E5E8510A7DF...     43.7441
# 77   0101000020E6100000B94BF948BEDB53C0D4C5FE9626D6...     43.6868
# 92   0101000020E6100000DF7A0DF462E653C0EC776DDE14E0...     43.7439
# 110  0101000020E6100000BBD25DD28BE653C029598BA581DC...     43.8194
#
#      lon_pickup  lat_dropoff  lon_dropoff  keep  latitude  longitude
# 6      -79.6076      43.6895     -79.6022   1.0       NaN        NaN
# 65     -79.4847      43.7473     -79.5798   1.0       NaN        NaN
# 77     -79.5956      43.6731     -79.4335   1.0       NaN        NaN
# 92     -79.6055      43.7506     -79.5998   1.0       NaN        NaN
# 110    -79.2132      43.7227     -79.6023   1.0       NaN        NaN

# %%
# Test again!! => ok
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'pickup_gc_intersection_id'].count())
df.loc[(df['dropoff_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'dropoff_gc_intersection_id'].count()
# Out:
# 12
# 151

# %%
# Test again!! => ok
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']==this_day) & 
             (df['pickup_ward2018']==ward) &
             (df['timewindow']==this_tod),'pickup_gc_intersection_id'].count())
# Out:
# 12

# %% [markdown]
# ## 3. Mark if row is a pickup or a dropoff
# pickup is where pickup ward == ward, dropoff is where dropoff_ward == ward
# Note that a row can contain **both** a pickup and a dropoff !!!

# %%
df['pu'] = np.nan
df['do'] = np.nan

# %%
df.loc[df['pickup_ward2018']==ward, 'pu'] = 1

# %%
df.loc[df['dropoff_ward2018']==ward, 'do'] = 1

# %%
# Check
df.loc[df['dropoff_ward2018']==ward, 
       ['dow','timewindow','pickup_datetime','dropoff_datetime',
        'lat_pickup','lon_pickup','pickup_gc_intersection_id',
        'lat_dropoff','lon_dropoff','dropoff_gc_intersection_id',
        'pickup_ward2018','dropoff_ward2018','pu','do']].head(11)
# Out:
#         dow       timewindow      pickup_datetime     dropoff_datetime  \
# 6    Monday          nightII  2018-09-03 00:00:00  2018-09-03 00:13:26
# 65   Monday          nightII  2018-09-03 00:00:00  2018-09-03 00:13:36
# 92   Monday          nightII  2018-09-03 01:00:00  2018-09-03 01:04:16
# 110  Monday          nightII  2018-09-03 00:00:00  2018-09-03 00:42:09
# 111  Monday          nightII  2018-09-03 00:00:00  2018-09-03 00:08:17
# 126  Monday          nightII  2018-09-03 00:00:00  2018-09-03 00:03:47
# 181  Monday          nightII  2018-09-03 00:00:00  2018-09-03 00:30:08
# 277  Monday          nightII  2018-09-03 01:00:00  2018-09-03 01:04:27
# 389  Monday  outside_windows  2018-09-03 02:00:00  2018-09-03 02:07:40
# 392  Monday  outside_windows  2018-09-03 02:00:00  2018-09-03 02:07:25
# 394  Monday  outside_windows  2018-09-03 02:00:00  2018-09-03 02:23:30
#
#      lat_pickup  lon_pickup  pickup_gc_intersection_id  lat_dropoff  \
# 6       43.7252    -79.6076                   30082386      43.6895
# 65      43.7441    -79.4847                   30109966      43.7473
# 92      43.7439    -79.6055                   13451763      43.7506
# 110     43.8194    -79.2132                   13441921      43.7227
# 111     43.7585    -79.5930                   30091827      43.7338
# 126     43.7199    -79.5608                   13455313      43.7133
# 181     43.7923    -79.4411                   13444614      43.7169
# 277     43.6908    -79.5974                   13460293      43.6783
# 389     43.7297    -79.5643                   13453937      43.7325
# 392     43.7087    -79.4781                   13456952      43.7015
# 394     43.6453    -79.3892                   13467525      43.7463
#
#      lon_dropoff  dropoff_gc_intersection_id  pickup_ward2018  \
# 6       -79.6022                    13460542              1.0
# 65      -79.5798                    13451158              6.0
# 92      -79.5998                    13450652              1.0
# 110     -79.6023                    14075750             25.0
# 111     -79.5935                    13453287              1.0
# 126     -79.5597                    13456371              1.0
# 181     -79.6035                    13455879             18.0
# 277     -79.5850                    13462531              1.0
# 389     -79.6010                    13453509              1.0
# 392     -79.5573                    13458251              5.0
# 394     -79.5882                    13451342             10.0
#
#      dropoff_ward2018   pu   do
# 6                 1.0  1.0  1.0
# 65                1.0  NaN  1.0
# 92                1.0  1.0  1.0
# 110               1.0  NaN  1.0
# 111               1.0  1.0  1.0
# 126               1.0  1.0  1.0
# 181               1.0  NaN  1.0
# 277               1.0  1.0  1.0
# 389               1.0  1.0  1.0
# 392               1.0  NaN  1.0
# 394               1.0  NaN  1.0

# %%
thisid = 13453946

print(df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak'),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak')][['pickup_ward2018','dropoff_ward2018','dow','timewindow','pu','do']]
# Out:
# 17
#         pickup_ward2018  dropoff_ward2018     dow timewindow   pu   do
# 21103              10.0               1.0  Monday     amPeak  NaN  1.0
# 55108               1.0               1.0  Monday     amPeak  1.0  1.0
# 125591              7.0               1.0  Monday     amPeak  NaN  1.0
# 125592              1.0               1.0  Monday     amPeak  1.0  1.0
# 133786              5.0               1.0  Monday     amPeak  NaN  1.0
# 133882             15.0               1.0  Monday     amPeak  NaN  1.0
# 141570              7.0               1.0  Monday     amPeak  NaN  1.0
# 286280              3.0               1.0  Monday     amPeak  NaN  1.0
# 286295              1.0               1.0  Monday     amPeak  1.0  1.0
# 298822              8.0               1.0  Monday     amPeak  NaN  1.0
# 298823              8.0               1.0  Monday     amPeak  NaN  1.0
# 347543              8.0               1.0  Monday     amPeak  NaN  1.0
# 355990              1.0               1.0  Monday     amPeak  1.0  1.0
# 361525              9.0               1.0  Monday     amPeak  NaN  1.0
# 370813              8.0               1.0  Monday     amPeak  NaN  1.0
# 374278              7.0               1.0  Monday     amPeak  NaN  1.0
# 384418              7.0               1.0  Monday     amPeak  NaN  1.0

# %% [markdown]
# ## 4a. Aggregate pickups and dropoffs for this_tod

# %%
list(df)
# Out:
# ['pickup_datetime',
#  'dropoff_datetime',
#  'pickup_ward2018',
#  'dropoff_ward2018',
#  'pickup_gc_intersection_id',
#  'dropoff_gc_intersection_id',
#  'dow',
#  'timewindow',
#  'pickup_geom',
#  'dropoff_geom',
#  'lat_pickup',
#  'lon_pickup',
#  'lat_dropoff',
#  'lon_dropoff',
#  'keep',
#  'latitude',
#  'longitude',
#  'pu',
#  'do']

# %%
df_agg_pu = pd.DataFrame()

df_agg_pu = df.loc[(df['pickup_ward2018']==ward) & (df['timewindow']==this_tod)].groupby(
    ['dow','timewindow','lat_pickup','lon_pickup','pickup_gc_intersection_id']
    ).size().reset_index(name='pcounts')

df_agg_pu = df_agg_pu.rename(columns={'lat_pickup': 'latitude'})
df_agg_pu = df_agg_pu.rename(columns={'lon_pickup': 'longitude'})
df_agg_pu = df_agg_pu.rename(columns={'pickup_gc_intersection_id': 'intersection_id'})

df_agg_pu.head(11)
# Out:
#        dow timewindow  latitude  longitude  intersection_id  pcounts
# 0   Monday     amPeak   43.6743   -79.5654         13463160        3
# 1   Monday     amPeak   43.6757   -79.5684         13462944       64
# 2   Monday     amPeak   43.6763   -79.5704         13462841        2
# 3   Monday     amPeak   43.6768   -79.5642         13462745        5
# 4   Monday     amPeak   43.6771   -79.5712         13462701        1
# 5   Monday     amPeak   43.6775   -79.5680         13462642        3
# 6   Monday     amPeak   43.6781   -79.5688         13462541        1
# 7   Monday     amPeak   43.6782   -79.5648         13462514        3
# 8   Monday     amPeak   43.6783   -79.5850         13462531        3
# 9   Monday     amPeak   43.6797   -79.5694         13462270        1
# 10  Monday     amPeak   43.6807   -79.5669         13462062        2

# %%
df_agg_pu.loc[(df_agg_pu['intersection_id']==13453946) & 
                 (df_agg_pu['timewindow']=='amPeak')                 
                ]
# Out:
#         dow timewindow  latitude  longitude  intersection_id  pcounts
# 275  Monday     amPeak   43.7301   -79.6049         13453946        2

# %%
df_agg_do = pd.DataFrame()

df_agg_do = df.loc[(df['dropoff_ward2018']==ward) & (df['timewindow']==this_tod)].groupby(
    ['dow','timewindow','lat_dropoff','lon_dropoff','dropoff_gc_intersection_id']
    ).size().reset_index(name='dcounts')

df_agg_do = df_agg_do.rename(columns={'lat_dropoff': 'latitude'})
df_agg_do = df_agg_do.rename(columns={'lon_dropoff': 'longitude'})
df_agg_do = df_agg_do.rename(columns={'dropoff_gc_intersection_id': 'intersection_id'})

df_agg_do.head(11)
# Out:
#        dow timewindow  latitude  longitude  intersection_id  dcounts
# 0   Monday     amPeak   43.6709   -79.5904         13463803        1
# 1   Monday     amPeak   43.6727   -79.5921         13463477        2
# 2   Monday     amPeak   43.6741   -79.5889         30029322       11
# 3   Monday     amPeak   43.6743   -79.5654         13463160        1
# 4   Monday     amPeak   43.6755   -79.5727         30108931        1
# 5   Monday     amPeak   43.6757   -79.5684         13462944        8
# 6   Monday     amPeak   43.6767   -79.5874         13462822        3
# 7   Monday     amPeak   43.6768   -79.5642         13462745        1
# 8   Monday     amPeak   43.6769   -79.5911         13462783        2
# 9   Monday     amPeak   43.6775   -79.5680         13462642        1
# 10  Monday     amPeak   43.6777   -79.5879         13462652        3

# %%
df_agg_do.loc[(df_agg_do['intersection_id']==13453946) & 
                 (df_agg_do['timewindow']=='amPeak')                 
                ]
# Out:
#         dow timewindow  latitude  longitude  intersection_id  dcounts
# 207  Monday     amPeak   43.7301   -79.6049         13453946       17

# %%
print(df_agg_pu.shape)
print(df_agg_do.shape)
# Out:
# (504, 6)
# (360, 6)

# %%
# Check for duplicate intersection_id
df_agg_pu.loc[df_agg_pu['intersection_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts]
# Index: []

# %%
# Check for duplicate intersection_id
df_agg_do.loc[df_agg_do['intersection_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, dcounts]
# Index: []

# %%
df_agg_pu.loc[(df_agg_pu['intersection_id']==20232410) ]
# Out:
#         dow timewindow  latitude  longitude  intersection_id  pcounts
# 266  Monday     amPeak   43.7289   -79.6057         20232410       12

# %%
df_agg_do.loc[(df_agg_do['intersection_id']==20232410) ]
# Out:
#         dow timewindow  latitude  longitude  intersection_id  dcounts
# 199  Monday     amPeak   43.7289   -79.6057         20232410      151

# %% [markdown]
# ## 5. Stack pickups on top of dropoffs

# %%
# Add empty columns to allow stacking

df_agg_pu=df_agg_pu.assign(dcounts=0)
df_agg_do=df_agg_do.assign(pcounts=0)

# %%
# stack
print(df_agg_pu.shape)
print(df_agg_do.shape)

df_merge=pd.concat([df_agg_pu, df_agg_do],sort=False)

print(df_merge.shape)
df_merge.head(11)
# Out:
# (504, 7)
# (360, 7)
# (864, 7)
#        dow timewindow  latitude  longitude  intersection_id  pcounts  dcounts
# 0   Monday     amPeak   43.6743   -79.5654         13463160        3        0
# 1   Monday     amPeak   43.6757   -79.5684         13462944       64        0
# 2   Monday     amPeak   43.6763   -79.5704         13462841        2        0
# 3   Monday     amPeak   43.6768   -79.5642         13462745        5        0
# 4   Monday     amPeak   43.6771   -79.5712         13462701        1        0
# 5   Monday     amPeak   43.6775   -79.5680         13462642        3        0
# 6   Monday     amPeak   43.6781   -79.5688         13462541        1        0
# 7   Monday     amPeak   43.6782   -79.5648         13462514        3        0
# 8   Monday     amPeak   43.6783   -79.5850         13462531        3        0
# 9   Monday     amPeak   43.6797   -79.5694         13462270        1        0
# 10  Monday     amPeak   43.6807   -79.5669         13462062        2        0

# %%
# Check
this_id=20232410  #13453946
df_merge.loc[df_merge['intersection_id']==this_id]
# Out:
#         dow timewindow  latitude  longitude  intersection_id  pcounts  dcounts
# 266  Monday     amPeak   43.7289   -79.6057         20232410       12        0
# 199  Monday     amPeak   43.7289   -79.6057         20232410        0      151

# %% [markdown]
# ## 6. Group on common `intersection_id`

# %%
df_merge.loc[df_merge['intersection_id']==13453946]
# Out:
#         dow timewindow  latitude  longitude  intersection_id  pcounts  dcounts
# 275  Monday     amPeak   43.7301   -79.6049         13453946        2        0
# 207  Monday     amPeak   43.7301   -79.6049         13453946        0       17

# %%
df_merge.loc[df_merge['intersection_id']==30092304]
# Out:
#        dow timewindow  latitude  longitude  intersection_id  pcounts  dcounts
# 15  Monday     amPeak   43.6816    -79.567         30092304        1        0

# %%
df_merge_gr=pd.DataFrame()

df_merge_gr=df_merge.groupby(['intersection_id','latitude','longitude'],as_index=False).sum()

print(df_merge_gr.shape)
df_merge_gr.head(11)
# Out:
# (669, 5)
#     intersection_id  latitude  longitude  pcounts  dcounts
# 0          13449225   43.7601   -79.5861        3        0
# 1          13449294   43.7596   -79.5899        0        1
# 2          13449386   43.7590   -79.5957        2        0
# 3          13449423   43.7588   -79.5904        1        0
# 4          13449457   43.7585   -79.5894        4        0
# 5          13449478   43.7584   -79.5978        1        0
# 6          13449748   43.7565   -79.5935        1        0
# 7          13449769   43.7566   -79.6048        1        0
# 8          13449783   43.7562   -79.5883       11        2
# 9          13449793   43.7562   -79.5918        1        0
# 10         13449815   43.7561   -79.5910        1        1

# %%
df_merge_gr.loc[df_merge_gr['intersection_id']==20232410]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 624         20232410   43.7289   -79.6057       12      151

# %%
# Check
this_id=20232410
df_merge_gr.loc[df_merge_gr['intersection_id']==this_id]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 624         20232410   43.7289   -79.6057       12      151

# %%
# Check
this_id=13453946
df_merge_gr.loc[df_merge_gr['intersection_id']==this_id]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 275         13453946   43.7301   -79.6049        2       17

# %% [markdown]
# ## 6. Make the dataframes for each layer!

# %% [markdown]
# ### a. PUDO layer from `df_merge_gr`

# %%
df_pudo_layer = pd.DataFrame()

# %%
df_pudo_layer = df_merge_gr.loc[(df_merge_gr['pcounts']>0) & (df_merge_gr['dcounts']>0)]

# %%
print(df_pudo_layer.shape)
# Out:
# (195, 5)

# %%
# Check
this_id=20232410   #13453946
df_pudo_layer.loc[df_pudo_layer['intersection_id']==this_id]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 624         20232410   43.7289   -79.6057       12      151

# %%
# Check
this_id=13453946
df_pudo_layer.loc[df_pudo_layer['intersection_id']==this_id]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 275         13453946   43.7301   -79.6049        2       17

# %% [markdown]
# ### a. PU layer and DO layer from `df_merge`

# %%
df_pu_layer = pd.DataFrame()
df_do_layer = pd.DataFrame()

# %%
df_pu_layer = df_merge_gr.loc[(df_merge_gr['pcounts']>0) & (df_merge_gr['dcounts']==0)]
df_do_layer = df_merge_gr.loc[(df_merge_gr['pcounts']==0) & (df_merge_gr['dcounts']>0)]

# %%
# Check
this_id=20232410   #13453946
df_pu_layer.loc[df_pu_layer['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [intersection_id, latitude, longitude, pcounts, dcounts]
# Index: []

# %%
# Check
this_id=13453946
df_pu_layer.loc[df_pu_layer['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [intersection_id, latitude, longitude, pcounts, dcounts]
# Index: []

# %%
# Check
this_id=13453946
df_do_layer.loc[df_do_layer['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [intersection_id, latitude, longitude, pcounts, dcounts]
# Index: []

# %% [markdown]
# # Histograms of counts
# https://mode.com/example-gallery/python_histogram/

# %%
print('w' +repr(ward), this_day, this_tod)
# Out:
# w1 Monday amPeak

# %%
# Check for duplicate intersection_id
df_pu_layer.loc[df_pu_layer['intersection_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [intersection_id, latitude, longitude, pcounts, dcounts]
# Index: []

# %%
print(df_pu_layer.shape)
print(df_pu_layer['pcounts'].max())
print(df_pu_layer['pcounts'].min())
df_pu_layer.head(5)
# Out:
# (309, 5)
# 9
# 1
#    intersection_id  latitude  longitude  pcounts  dcounts
# 0         13449225   43.7601   -79.5861        3        0
# 2         13449386   43.7590   -79.5957        2        0
# 3         13449423   43.7588   -79.5904        1        0
# 4         13449457   43.7585   -79.5894        4        0
# 5         13449478   43.7584   -79.5978        1        0

# %%
df_pu_layer.hist(column='pcounts',bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f10cc68dc18>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

n = 10  #20
print(df_pu_layer['pcounts'].max())
print('bin width: ' + repr(df_pu_layer['pcounts'].max()/n))

ax = df_pu_layer.hist(column='pcounts', bins=n, grid=True, figsize=(9,8), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("pcounts", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Bin counts", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
# Out:
# 9
# bin width: 0.9
# /home/test/anaconda3/envs/vfh/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

n = 35
print(df_do_layer['dcounts'].max())
print('bin width: ' + repr(df_do_layer['dcounts'].max()/n))

ax = df_do_layer.hist(column='dcounts', bins=n, grid=True, figsize=(9,8), color='brown', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("pcounts", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Bin counts", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
# Out:
# 23
# bin width: 0.6571428571428571

# %%
df=
# Out:
#   File "<ipython-input-63-02c2a1c0215a>", line 1
#     df=
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Save to geojson

# %%
print('w' +repr(ward), this_day, this_tod)
# Out:
# w1 Monday amPeak

# %%
df_do_layer.head(5)
# Out:
#     intersection_id  latitude  longitude  pcounts  dcounts
# 1          13449294   43.7596   -79.5899        0        1
# 16         13450025   43.7549   -79.5987        0        1
# 18         13450070   43.7546   -79.5978        0        1
# 19         13450164   43.7542   -79.6198        0        1
# 20         13450172   43.7538   -79.5974        0        1

# %%
this_id=13453946
df_pudo_layer.loc[df_pudo_layer['intersection_id']==this_id]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 275         13453946   43.7301   -79.6049        2       17

# %%
df_pudo_layer.sort_values('dcounts',ascending=False).head(9)
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 624         20232410   43.7289   -79.6057       12      151
# 260         13453797   43.7311   -79.6078        1       40
# 585         13462101   43.6808   -79.5929        6       26
# 176         13452853   43.7368   -79.5917        1       24
# 557         13460389   43.6901   -79.5845        7       22
# 457         13457060   43.7092   -79.5655        3       20
# 622         20232392   43.7284   -79.6044        1       19
# 275         13453946   43.7301   -79.6049        2       17
# 67          13451253   43.7468   -79.5838       38       16

# %% [markdown]
# ## Apply cut-off filter
# Only counts > `c` will be saved.

# %%
c = 9 # cut-off

# %%
print(df_pu_layer.loc[(df_pu_layer['pcounts']>=c),'pcounts'].count())
df_pu_layer.loc[(df_pu_layer['pcounts']>=c)]
# Out:
# 1
#      intersection_id  latitude  longitude  pcounts  dcounts
# 582         13462021   43.6809   -79.5661        9        0

# %%
print(df_do_layer.loc[(df_do_layer['dcounts']>=c),'dcounts'].count())
df_do_layer.loc[(df_do_layer['dcounts']>=c)]
# Out:
# 8
#      intersection_id  latitude  longitude  pcounts  dcounts
# 272         13453918   43.7301   -79.5886        0        9
# 360         13455043   43.7217   -79.5715        0       20
# 467         13457663   43.7058   -79.5903        0       10
# 536         13459530   43.6950   -79.6031        0       13
# 542         13459809   43.6934   -79.5885        0       23
# 561         13460542   43.6895   -79.6022        0       20
# 587         13462468   43.6787   -79.5883        0       10
# 634         30029322   43.6741   -79.5889        0       11

# %%
print(df_pudo_layer.loc[((df_pudo_layer['pcounts']+df_pudo_layer['dcounts']) >= c),'dcounts'].count())
df_pudo_layer.loc[(df_pudo_layer['dcounts']>=c)]
# Out:
# 59
#      intersection_id  latitude  longitude  pcounts  dcounts
# 67          13451253   43.7468   -79.5838       38       16
# 176         13452853   43.7368   -79.5917        1       24
# 260         13453797   43.7311   -79.6078        1       40
# 262         13453815   43.7309   -79.5995        4       14
# 275         13453946   43.7301   -79.6049        2       17
# 382         13455408   43.7194   -79.5704        2       10
# 419         13455879   43.7169   -79.6035       17       14
# 440         13456327   43.7138   -79.5811        3       10
# 453         13456702   43.7115   -79.5714        3       11
# 457         13457060   43.7092   -79.5655        3       20
# 464         13457480   43.7065   -79.5662        4        9
# 475         13457902   43.7041   -79.5660        2       10
# 537         13459581   43.6944   -79.5760        1       13
# 555         13460340   43.6902   -79.5771        4       11
# 557         13460389   43.6901   -79.5845        7       22
# 559         13460458   43.6897   -79.5794        1       10
# 568         13461025   43.6868   -79.5956       34       16
# 569         13461072   43.6866   -79.5994       10       15
# 585         13462101   43.6808   -79.5929        6       26
# 589         13462531   43.6783   -79.5850        3       15
# 622         20232392   43.7284   -79.6044        1       19
# 624         20232410   43.7289   -79.6057       12      151
# 625         20232418   43.7277   -79.6088        1       11
# 640         30054780   43.7283   -79.6103        4       15

# %%
this_id=13453946
df_pudo_layer.loc[ ((df_pudo_layer['pcounts']+df_pudo_layer['dcounts']) >= c) &
                  (df_pudo_layer['intersection_id'] == thisid)
                                                    ]
# Out:
#      intersection_id  latitude  longitude  pcounts  dcounts
# 275         13453946   43.7301   -79.6049        2       17

# %%
geojson_pu_layer = df_to_geojson(df_pu_layer.loc[(df_pu_layer['pcounts']>=c)], ['pcounts'])

# %%
geojson_do_layer = df_to_geojson(df_do_layer.loc[(df_do_layer['dcounts']>=c)], ['dcounts'])

# %%
# geojson_pudo_layer = df_to_geojson(df_pudo_layer.loc[(df_pudo_layer['pcounts']>=c) &
#                                                      (df_pudo_layer['dcounts']>=c)
#                                                     ], ['pcounts','dcounts'])

geojson_pudo_layer = df_to_geojson(df_pudo_layer.loc[
    ((df_pudo_layer['pcounts']+df_pudo_layer['dcounts']) >= c)
                                                    ], ['pcounts','dcounts'])

# %% [markdown]
# # Write geojson to file

# %% [markdown]
# ## Aggregated points

# %%
print('w' +repr(ward), this_day, this_tod)
# Out:
# w1 Monday amPeak

# %%
mydir = '../../../Documents/PROJECTS/VFH/COT_PAGE/INTERIM_DATA/INDIVIDUAL_GEOJSONS/'
# mydir = '/home/nangini/Documents/PROJECTS/BDITTO/VFH/DATA_STORY/DATA/INDIVIDUAL_GEOJSONS/'


output_filename = mydir + 'w' + repr(ward) + '_092018_' + this_day + '_' + this_tod + '_pu_cutoff.geojson'

with open(output_filename, 'w') as output_file:
    output_file.write('')
    json.dump(geojson_pu_layer, output_file, indent=2)

# %%
output_filename = mydir + 'w' + repr(ward) + '_092018_' + this_day + '_' + this_tod + '_do_cutoff.geojson'

with open(output_filename, 'w') as output_file:
    output_file.write('')
    json.dump(geojson_do_layer, output_file, indent=2)

# %%
output_filename = mydir + 'w' + repr(ward) + '_092018_' + this_day + '_' + this_tod + '_pudo_cutoff.geojson'

with open(output_filename, 'w') as output_file:
    output_file.write('')
    json.dump(geojson_pudo_layer, output_file, indent=2)

# %% [markdown]
# `
# $ ls -lh ~/Documents/PROJECTS/VFH/COT_PAGE/INTERIM_DATA/INDIVIDUAL_GEOJSONS/
# total 216K
# -rw-r--r-- 1 test test 109K Dec  9 11:23 w1_092018_Monday_pmPeak_do_agg.geojson
# -rw-r--r-- 1 test test 104K Dec  9 11:23 w1_092018_Monday_pmPeak_pu_agg.geojson
# `

# %% [markdown]
# `
# $ ls -lh src/geojson/
# -rw-r--r-- 1 test test 328K Dec  4 15:46 w1_092018_Monday_amPeak_agg.geojson
# -rw-r--r-- 1 test test 753K Dec  4 13:51 w1_092018_Monday_amPeak.geojson
# `
