# %% [markdown]
# # Create geojson file from list of PUDO coords
# See /home/test/Documents/PROJECTS/VFH/iPython_Notebooks/dv_pudo_profiles.ipynb for more info.
#
# ref: https://geoffboeing.com/2015/10/exporting-python-data-geojson/
# Huom: `with open(output_filename, 'wb') as output_file:` should be `'w'` not `'wb'`
#
# **Resources**
# geoJSON minifier: https://jsonformatter.org/json-minify

# %%
import sys
sys.executable
# Out:
# '/home/test/anaconda3/envs/vfh/bin/python'

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pandas.io.sql as pandasql
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker

from IPython.display import HTML, display
import datetime
import matplotlib.dates as mdates
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import os

from datetime import datetime

import json

# %% [markdown]
# # Functions

# %%
# https://geoffboeing.com/2015/10/exporting-python-data-geojson/
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = int(row[prop])
        geojson['features'].append(feature)
    return geojson

# %% [markdown]
# # GeoJSON properties for file

# %%
# Define the properties of the PUDO geojson file
prop = ['type','counts', 'overlap']

# %% [markdown]
# # Variables

# %%
ward=10
this_day = "Monday"
this_tod = "amPeak"

# %%
if ward == 1:
    test_id1 = 20232410   # 13454935
    test_id2 = 13453946
elif ward == 10:
    test_id1 = 13467106 # Adelaide and John
    test_id2 = 13466303

# %% [markdown]
# # Read PUDO data from csv file

# %%
fname = '../../../Documents/PROJECTS/VFH/COT_PAGE/INTERIM_DATA/FROM_PGADMIN/all_pudo_mon.csv'
# fname = '~/Documents/PROJECTS/BDITTO/VFH/DATA_STORY/DATA/from_pgAdmin/all_pudo_mon.csv'

df = pd.read_csv(fname)

print(df.shape)
df.head(5)
# Out:
# (494842, 14)
#        pickup_datetime     dropoff_datetime  pickup_ward2018  \
# 0  2018-09-03 00:00:00  2018-09-03 00:34:01             18.0
# 1  2018-09-03 00:00:00  2018-09-03 00:10:54             10.0
# 2  2018-09-03 00:00:00  2018-09-03 00:12:34             13.0
# 3  2018-09-03 00:00:00  2018-09-03 00:24:18             13.0
# 4  2018-09-03 00:00:00  2018-09-03 00:18:21              8.0
#
#    dropoff_ward2018  pickup_gc_intersection_id  dropoff_gc_intersection_id  \
# 0              10.0                   13447475                    13467654
# 1              13.0                   13467763                    13464030
# 2              10.0                   13464551                    13467763
# 3               3.0                   13465140                    13470547
# 4              13.0                   14044860                    14673305
#
#       dow timewindow                                        pickup_geom  \
# 0  Monday    nightII  0101000020E61000005BE2AF6670DA53C01D22DBEA93E2...
# 1  Monday    nightII  0101000020E610000051E519D30AD953C0C23B89A05BD2...
# 2  Monday    nightII  0101000020E6100000A342F6F3C6D753C0E8EE4CFEEDD4...
# 3  Monday    nightII  0101000020E6100000DF5023ED39D853C020ED2E3976D4...
# 4  Monday    nightII  0101000020E6100000A37FC1EFB8DC53C070C432B4FCDB...
#
#                                         dropoff_geom  lat_pickup  lon_pickup  \
# 0  0101000020E610000013E6CE309BD953C0938FE7777DD2...   43.770139  -79.413110
# 1  0101000020E610000079E6DB3E68D853C00F3AF08356D5...   43.643421  -79.391286
# 2  0101000020E610000051E519D30AD953C0C23B89A05BD2...   43.663513  -79.371518
# 3  0101000020E610000004410BFFE5E153C041B447898CCC...   43.659858  -79.378536
# 4  0101000020E61000008C84E11C68D853C062D98093A3D5...   43.718649  -79.448788
#
#    lat_dropoff  lon_dropoff
# 0    43.644454   -79.400097
# 1    43.666703   -79.381363
# 2    43.643421   -79.391286
# 3    43.598039   -79.529663
# 4    43.669054   -79.381355

# %%
list(df)
# Out:
# ['pickup_datetime',
#  'dropoff_datetime',
#  'pickup_ward2018',
#  'dropoff_ward2018',
#  'pickup_gc_intersection_id',
#  'dropoff_gc_intersection_id',
#  'dow',
#  'timewindow',
#  'pickup_geom',
#  'dropoff_geom',
#  'lat_pickup',
#  'lon_pickup',
#  'lat_dropoff',
#  'lon_dropoff']

# %%
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'pickup_gc_intersection_id'].count())
df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak')]
# Out:
# 62
#             pickup_datetime     dropoff_datetime  pickup_ward2018  \
# 23281   2018-09-03 07:00:00  2018-09-03 07:15:29             10.0
# 30889   2018-09-03 07:00:00  2018-09-03 07:12:22             10.0
# 57648   2018-09-10 08:00:00  2018-09-10 08:07:13             10.0
# 58455   2018-09-10 07:00:00  2018-09-10 07:03:32             10.0
# 63584   2018-09-10 07:00:00  2018-09-10 07:38:00             10.0
# 64637   2018-09-10 08:00:00  2018-09-10 08:05:30             10.0
# 66260   2018-09-10 08:00:00  2018-09-10 08:08:51             10.0
# 66261   2018-09-10 08:00:00  2018-09-10 08:08:51             10.0
# 70212   2018-09-10 07:00:00  2018-09-10 07:05:35             10.0
# 70842   2018-09-10 07:00:00  2018-09-10 07:36:04             10.0
# 71852   2018-09-10 08:00:00  2018-09-10 08:07:00             10.0
# 73264   2018-09-10 07:00:00  2018-09-10 07:05:23             10.0
# 77844   2018-09-10 07:00:00  2018-09-10 07:05:30             10.0
# 80973   2018-09-10 07:00:00  2018-09-10 07:06:31             10.0
# 82563   2018-09-10 08:00:00  2018-09-10 08:09:18             10.0
# 86881   2018-09-10 07:00:00  2018-09-10 07:06:20             10.0
# 88772   2018-09-10 08:00:00  2018-09-10 08:08:40             10.0
# 92799   2018-09-10 07:00:00  2018-09-10 07:15:22             10.0
# 93567   2018-09-10 08:00:00  2018-09-10 08:10:12             10.0
# 95634   2018-09-17 07:00:00  2018-09-17 07:03:07             10.0
# 97802   2018-09-17 07:00:00  2018-09-17 07:05:29             10.0
# 98522   2018-09-17 08:00:00  2018-09-17 08:04:08             10.0
# 99051   2018-09-17 07:00:00  2018-09-17 07:07:12             10.0
# 99262   2018-09-17 08:00:00  2018-09-17 08:07:48             10.0
# 103111  2018-09-17 07:00:00  2018-09-17 07:07:24             10.0
# 103867  2018-09-17 08:00:00  2018-09-17 08:06:07             10.0
# 103868  2018-09-17 08:00:00  2018-09-17 08:06:07             10.0
# 104543  2018-09-17 08:00:00  2018-09-17 08:07:29             10.0
# 105077  2018-09-17 08:00:00  2018-09-17 08:08:16             10.0
# 108466  2018-09-17 08:00:00  2018-09-17 08:07:28             10.0
# ...                     ...                  ...              ...
# 111139  2018-09-17 07:00:00  2018-09-17 07:21:11             10.0
# 112381  2018-09-17 08:00:00  2018-09-17 08:05:53             10.0
# 113899  2018-09-17 07:00:00  2018-09-17 07:04:38             10.0
# 114859  2018-09-17 08:00:00  2018-09-17 08:05:02             10.0
# 115166  2018-09-17 07:00:00  2018-09-17 07:33:30             10.0
# 126623  2018-09-17 08:00:00  2018-09-17 08:08:42             10.0
# 127438  2018-09-17 08:00:00  2018-09-17 08:11:20             10.0
# 135513  2018-09-24 08:00:00  2018-09-24 08:06:18             10.0
# 139644  2018-09-24 07:00:00  2018-09-24 07:24:11             10.0
# 144835  2018-09-24 08:00:00  2018-09-24 08:05:06             10.0
# 149547  2018-09-24 08:00:00  2018-09-24 08:12:56             10.0
# 150445  2018-09-24 08:00:00  2018-09-24 08:08:49             10.0
# 153284  2018-09-24 07:00:00  2018-09-24 07:08:08             10.0
# 159207  2018-09-24 08:00:00  2018-09-24 08:07:04             10.0
# 159539  2018-09-24 08:00:00  2018-09-24 08:06:09             10.0
# 172307  2018-09-17 08:00:00  2018-09-17 08:24:06             10.0
# 181277  2018-09-03 08:00:00  2018-09-03 08:06:48             10.0
# 203240  2018-09-10 08:00:00  2018-09-10 08:05:47             10.0
# 203550  2018-09-10 08:00:00  2018-09-10 08:07:41             10.0
# 209474  2018-09-10 07:00:00  2018-09-10 07:09:45             10.0
# 211591  2018-09-10 08:00:00  2018-09-10 08:19:08             10.0
# 218140  2018-09-10 08:00:00  2018-09-10 08:12:07             10.0
# 220925  2018-09-10 08:00:00  2018-09-10 08:06:31             10.0
# 223604  2018-09-10 07:00:00  2018-09-10 07:09:00             10.0
# 224052  2018-09-10 07:00:00  2018-09-10 07:05:50             10.0
# 224864  2018-09-10 08:00:00  2018-09-10 08:05:51             10.0
# 225436  2018-09-10 07:00:00  2018-09-10 07:05:36             10.0
# 247004  2018-09-17 07:00:00  2018-09-17 07:13:34             10.0
# 257685  2018-09-24 07:00:00  2018-09-24 07:05:25             10.0
# 274862  2018-09-24 08:00:00  2018-09-24 08:54:24             10.0
#
#         dropoff_ward2018  pickup_gc_intersection_id  \
# 23281                8.0                   13467106
# 30889               13.0                   13467106
# 57648               10.0                   13467106
# 58455               10.0                   13467106
# 63584               16.0                   13467106
# 64637               10.0                   13467106
# 66260               10.0                   13467106
# 66261               10.0                   13467106
# 70212               13.0                   13467106
# 70842               20.0                   13467106
# 71852               10.0                   13467106
# 73264               10.0                   13467106
# 77844               10.0                   13467106
# 80973               10.0                   13467106
# 82563               10.0                   13467106
# 86881               11.0                   13467106
# 88772               13.0                   13467106
# 92799               11.0                   13467106
# 93567               10.0                   13467106
# 95634               10.0                   13467106
# 97802               11.0                   13467106
# 98522               10.0                   13467106
# 99051               11.0                   13467106
# 99262               13.0                   13467106
# 103111              13.0                   13467106
# 103867              10.0                   13467106
# 103868              10.0                   13467106
# 104543              11.0                   13467106
# 105077              13.0                   13467106
# 108466              10.0                   13467106
# ...                  ...                        ...
# 111139              19.0                   13467106
# 112381              10.0                   13467106
# 113899              13.0                   13467106
# 114859              10.0                   13467106
# 115166              16.0                   13467106
# 126623              11.0                   13467106
# 127438              13.0                   13467106
# 135513              10.0                   13467106
# 139644               3.0                   13467106
# 144835              10.0                   13467106
# 149547              11.0                   13467106
# 150445              11.0                   13467106
# 153284              11.0                   13467106
# 159207              10.0                   13467106
# 159539              10.0                   13467106
# 172307              14.0                   13467106
# 181277              11.0                   13467106
# 203240              10.0                   13467106
# 203550              13.0                   13467106
# 209474              13.0                   13467106
# 211591              13.0                   13467106
# 218140              11.0                   13467106
# 220925              10.0                   13467106
# 223604              13.0                   13467106
# 224052              13.0                   13467106
# 224864              13.0                   13467106
# 225436              11.0                   13467106
# 247004              10.0                   13467106
# 257685              11.0                   13467106
# 274862              22.0                   13467106
#
#         dropoff_gc_intersection_id     dow timewindow  \
# 23281                     13457779  Monday     amPeak
# 30889                     14020387  Monday     amPeak
# 57648                     14036081  Monday     amPeak
# 58455                     13466789  Monday     amPeak
# 63584                     13448747  Monday     amPeak
# 64637                     13466858  Monday     amPeak
# 66260                     13468181  Monday     amPeak
# 66261                     13468181  Monday     amPeak
# 70212                     13466551  Monday     amPeak
# 70842                     13452903  Monday     amPeak
# 71852                     13467303  Monday     amPeak
# 73264                     13467389  Monday     amPeak
# 77844                     13467083  Monday     amPeak
# 80973                     20034906  Monday     amPeak
# 82563                     13467389  Monday     amPeak
# 86881                     13465400  Monday     amPeak
# 88772                     13467080  Monday     amPeak
# 92799                     13463548  Monday     amPeak
# 93567                     13467389  Monday     amPeak
# 95634                     20034906  Monday     amPeak
# 97802                     13464999  Monday     amPeak
# 98522                     13975054  Monday     amPeak
# 99051                     13465527  Monday     amPeak
# 99262                     13467080  Monday     amPeak
# 103111                    13466034  Monday     amPeak
# 103867                    13468065  Monday     amPeak
# 103868                    13468065  Monday     amPeak
# 104543                    13463548  Monday     amPeak
# 105077                    14036812  Monday     amPeak
# 108466                    13467825  Monday     amPeak
# ...                            ...     ...        ...
# 111139                    13459794  Monday     amPeak
# 112381                    13975054  Monday     amPeak
# 113899                    13466232  Monday     amPeak
# 114859                    13467083  Monday     amPeak
# 115166                    13448747  Monday     amPeak
# 126623                    13465011  Monday     amPeak
# 127438                    13465714  Monday     amPeak
# 135513                    13467163  Monday     amPeak
# 139644                    13470354  Monday     amPeak
# 144835                    13975054  Monday     amPeak
# 149547                    13463436  Monday     amPeak
# 150445                    13465011  Monday     amPeak
# 153284                    13463548  Monday     amPeak
# 159207                    13467163  Monday     amPeak
# 159539                    13467389  Monday     amPeak
# 172307                    14024410  Monday     amPeak
# 181277                    13466158  Monday     amPeak
# 203240                    13466752  Monday     amPeak
# 203550                    13466207  Monday     amPeak
# 209474                    13463931  Monday     amPeak
# 211591                    13465590  Monday     amPeak
# 218140                    13463511  Monday     amPeak
# 220925                    14621058  Monday     amPeak
# 223604                    13466207  Monday     amPeak
# 224052                    13466207  Monday     amPeak
# 224864                    14673831  Monday     amPeak
# 225436                    13465023  Monday     amPeak
# 247004                    13468309  Monday     amPeak
# 257685                    13465023  Monday     amPeak
# 274862                    13442762  Monday     amPeak
#
#                                               pickup_geom  \
# 23281   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 30889   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 57648   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 58455   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 63584   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 64637   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 66260   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 66261   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 70212   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 70842   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 71852   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 73264   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 77844   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 80973   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 82563   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 86881   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 88772   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 92799   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 93567   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 95634   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 97802   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 98522   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 99051   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 99262   0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 103111  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 103867  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 103868  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 104543  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 105077  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 108466  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# ...                                                   ...
# 111139  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 112381  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 113899  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 114859  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 115166  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 126623  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 127438  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 135513  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 139644  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 144835  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 149547  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 150445  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 153284  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 159207  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 159539  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 172307  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 181277  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 203240  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 203550  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 209474  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 211591  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 218140  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 220925  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 223604  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 224052  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 224864  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 225436  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 247004  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 257685  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
# 274862  0101000020E61000005EDB6E91FAD853C025A398F6ECD2...
#
#                                              dropoff_geom  lat_pickup  \
# 23281   0101000020E6100000C0DF9FBA08DB53C0EFD33A6FF8D9...   43.647857
# 30889   0101000020E6100000A27CF0C3A9D853C042864949B3D4...   43.647857
# 57648   0101000020E61000009403BF0B90D853C03715C0CCABD2...   43.647857
# 58455   0101000020E6100000287B62D574D853C04C78569326D3...   43.647857
# 63584   0101000020E6100000689BA10CA3D653C01E97991B51E1...   43.647857
# 64637   0101000020E6100000406EE54395D853C02908239818D3...   43.647857
# 66260   0101000020E6100000560A723155D853C0A38C7E55EAD1...   43.647857
# 66261   0101000020E6100000560A723155D853C0A38C7E55EAD1...   43.647857
# 70212   0101000020E610000086DEC9443DD853C0AAD43DC955D3...   43.647857
# 70842   0101000020E6100000854D4E01F1D053C0FD90635DAFDD...   43.647857
# 71852   0101000020E6100000E55B788E83D853C0AE24C8F4C3D2...   43.647857
# 73264   0101000020E6100000837355BF43D853C026BA31B4AFD2...   43.647857
# 77844   0101000020E610000051EA288D8CD853C04A7CA72FEFD2...   43.647857
# 80973   0101000020E6100000AF5EFE705BD853C093409CEABDD2...   43.647857
# 82563   0101000020E6100000837355BF43D853C026BA31B4AFD2...   43.647857
# 86881   0101000020E6100000A2F824BC0CD953C0D364290646D4...   43.647857
# 88772   0101000020E6100000946AF0D526D853C0453192A0ECD2...   43.647857
# 92799   0101000020E6100000396933B1EDD853C028C639B7B7D5...   43.647857
# 93567   0101000020E6100000837355BF43D853C026BA31B4AFD2...   43.647857
# 95634   0101000020E6100000AF5EFE705BD853C093409CEABDD2...   43.647857
# 97802   0101000020E6100000F538EDD8B1D853C004EE929B95D4...   43.647857
# 98522   0101000020E61000003FC2DF186AD853C0E9C6AAF74AD2...   43.647857
# 99051   0101000020E6100000F387E064EDD853C0C10FC7ED29D4...   43.647857
# 99262   0101000020E6100000946AF0D526D853C0453192A0ECD2...   43.647857
# 103111  0101000020E61000001256BEC23DD853C0532F67D2C0D3...   43.647857
# 103867  0101000020E6100000DA50F2695CD853C0A0DEC9FD07D2...   43.647857
# 103868  0101000020E6100000DA50F2695CD853C0A0DEC9FD07D2...   43.647857
# 104543  0101000020E6100000396933B1EDD853C028C639B7B7D5...   43.647857
# 105077  0101000020E610000069F28D1B30D853C03CC855A644D3...   43.647857
# 108466  0101000020E6100000D98CD6C803D853C0FA22D9D745D2...   43.647857
# ...                                                   ...         ...
# 111139  0101000020E6100000541B55B3F2D253C0C7CC7FF43FD8...   43.647857
# 112381  0101000020E61000003FC2DF186AD853C0E9C6AAF74AD2...   43.647857
# 113899  0101000020E6100000226D8D4F1BD853C0B4E9C6C394D3...   43.647857
# 114859  0101000020E610000051EA288D8CD853C04A7CA72FEFD2...   43.647857
# 115166  0101000020E6100000689BA10CA3D653C01E97991B51E1...   43.647857
# 126623  0101000020E6100000F012BD088AD953C09A7C9C3198D4...   43.647857
# 127438  0101000020E61000009D35291961D853C0FF2BD29402D4...   43.647857
# 135513  0101000020E61000009A8E757B4DD853C0929E96DDDBD2...   43.647857
# 139644  0101000020E61000007B0E942A3DE153C06107C1EF4ECD...   43.647857
# 144835  0101000020E61000003FC2DF186AD853C0E9C6AAF74AD2...   43.647857
# 149547  0101000020E61000007C31B722C1D853C0668A6EFAC9D5...   43.647857
# 150445  0101000020E6100000F012BD088AD953C09A7C9C3198D4...   43.647857
# 153284  0101000020E6100000396933B1EDD853C028C639B7B7D5...   43.647857
# 159207  0101000020E61000009A8E757B4DD853C0929E96DDDBD2...   43.647857
# 159539  0101000020E6100000837355BF43D853C026BA31B4AFD2...   43.647857
# 172307  0101000020E6100000C620F948BFD553C06517794A28D5...   43.647857
# 181277  0101000020E6100000BABFEC3140D953C037805BD0ABD3...   43.647857
# 203240  0101000020E6100000E55C9C8E66D953C020C6017A35D3...   43.647857
# 203550  0101000020E61000007CF8C2FC66D853C0093996479CD3...   43.647857
# 209474  0101000020E6100000497AAE75DDD853C01EA59B8F6ED5...   43.647857
# 211591  0101000020E61000009E4CCF0066D853C0ED7E9ED119D4...   43.647857
# 218140  0101000020E6100000CA36FEB141D953C021EF6456C0D5...   43.647857
# 220925  0101000020E6100000363D49368ED853C0D81E02B61FD2...   43.647857
# 223604  0101000020E61000007CF8C2FC66D853C0093996479CD3...   43.647857
# 224052  0101000020E61000007CF8C2FC66D853C0093996479CD3...   43.647857
# 224864  0101000020E61000001EB27EBC42D853C0822D286C3CD3...   43.647857
# 225436  0101000020E6100000D7A18B67BFD853C0AA71E88D90D4...   43.647857
# 247004  0101000020E61000003DAFB09430DB53C02558F606DAD1...   43.647857
# 257685  0101000020E6100000D7A18B67BFD853C0AA71E88D90D4...   43.647857
# 274862  0101000020E610000073BA78B47BD253C0D23F51714DE7...   43.647857
#
#         lon_pickup  lat_dropoff  lon_dropoff
# 23281   -79.390293    43.702894   -79.422408
# 30889   -79.390293    43.661721   -79.385362
# 57648   -79.390293    43.645868   -79.383792
# 58455   -79.390293    43.649615   -79.382131
# 63584   -79.390293    43.760288   -79.353702
# 64637   -79.390293    43.649188   -79.384110
# 66260   -79.390293    43.639964   -79.380200
# 66261   -79.390293    43.639964   -79.380200
# 70212   -79.390293    43.651055   -79.378740
# 70842   -79.390293    43.731914   -79.264710
# 71852   -79.390293    43.646605   -79.383030
# 73264   -79.390293    43.645987   -79.379135
# 77844   -79.390293    43.647924   -79.383579
# 80973   -79.390293    43.646421   -79.380581
# 82563   -79.390293    43.645987   -79.379135
# 86881   -79.390293    43.658387   -79.391402
# 88772   -79.390293    43.647846   -79.377370
# 92799   -79.390293    43.669669   -79.389508
# 93567   -79.390293    43.645987   -79.379135
# 95634   -79.390293    43.646421   -79.380581
# 97802   -79.390293    43.660816   -79.385855
# 98522   -79.390293    43.642913   -79.381476
# 99051   -79.390293    43.657530   -79.389489
# 99262   -79.390293    43.647846   -79.377370
# 103111  -79.390293    43.654322   -79.378770
# 103867  -79.390293    43.640869   -79.380640
# 103868  -79.390293    43.640869   -79.380640
# 104543  -79.390293    43.669669   -79.389508
# 105077  -79.390293    43.650533   -79.377936
# 108466  -79.390293    43.642756   -79.375231
# ...            ...          ...          ...
# 111139  -79.390293    43.689452   -79.296063
# 112381  -79.390293    43.642913   -79.381476
# 113899  -79.390293    43.652977   -79.376667
# 114859  -79.390293    43.647924   -79.383579
# 115166  -79.390293    43.760288   -79.353702
# 126623  -79.390293    43.660895   -79.399050
# 127438  -79.390293    43.656329   -79.380926
# 135513  -79.390293    43.647335   -79.379729
# 139644  -79.390293    43.603971   -79.519358
# 144835  -79.390293    43.642913   -79.381476
# 149547  -79.390293    43.670226   -79.386788
# 150445  -79.390293    43.660895   -79.399050
# 153284  -79.390293    43.669669   -79.389508
# 159207  -79.390293    43.647335   -79.379729
# 159539  -79.390293    43.645987   -79.379135
# 172307  -79.390293    43.665292   -79.339800
# 181277  -79.390293    43.653681   -79.394543
# 203240  -79.390293    43.650069   -79.396885
# 203550  -79.390293    43.653207   -79.381286
# 209474  -79.390293    43.667437   -79.388517
# 211591  -79.390293    43.657038   -79.381226
# 218140  -79.390293    43.669932   -79.394635
# 220925  -79.390293    43.641593   -79.383680
# 223604  -79.390293    43.653207   -79.381286
# 224052  -79.390293    43.653207   -79.381286
# 224864  -79.390293    43.650281   -79.379073
# 225436  -79.390293    43.660661   -79.386682
# 247004  -79.390293    43.639466   -79.424840
# 257685  -79.390293    43.660661   -79.386682
# 274862  -79.390293    43.807051   -79.288800
#
# [62 rows x 14 columns]

# %%
df.loc[(df['dropoff_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'dropoff_gc_intersection_id'].count()
# Out:
# 13

# %%
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['pickup_gc_intersection_id']==test_id1) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0), ['pickup_datetime','pickup_gc_intersection_id','dropoff_ward2018','dow','timewindow']]
# Out:
# 37
#             pickup_datetime  pickup_gc_intersection_id  dropoff_ward2018  \
# 10862   2018-09-10 17:00:00                   13467106              10.0
# 25290   2018-09-03 17:00:00                   13467106              10.0
# 30349   2018-09-03 16:00:00                   13467106              10.0
# 33318   2018-09-03 16:00:00                   13467106              10.0
# 35570   2018-09-03 16:00:00                   13467106              13.0
# 44020   2018-09-03 17:00:00                   13467106              10.0
# 61253   2018-09-10 16:00:00                   13467106              11.0
# 64828   2018-09-10 16:00:00                   13467106              10.0
# 70430   2018-09-10 16:00:00                   13467106              10.0
# 77031   2018-09-10 17:00:00                   13467106               3.0
# 113988  2018-09-17 16:00:00                   13467106              10.0
# 122954  2018-09-17 17:00:00                   13467106              13.0
# 138213  2018-09-24 17:00:00                   13467106              15.0
# 144299  2018-09-24 17:00:00                   13467106              10.0
# 146627  2018-09-24 16:00:00                   13467106              11.0
# 152044  2018-09-24 16:00:00                   13467106              13.0
# 159772  2018-09-24 17:00:00                   13467106              13.0
# 161482  2018-09-24 17:00:00                   13467106              13.0
# 170421  2018-09-10 16:00:00                   13467106              13.0
# 183507  2018-09-03 17:00:00                   13467106              13.0
# 188046  2018-09-03 17:00:00                   13467106              12.0
# 188749  2018-09-03 17:00:00                   13467106              19.0
# 202508  2018-09-10 17:00:00                   13467106              13.0
# 208302  2018-09-10 17:00:00                   13467106              10.0
# 208303  2018-09-10 17:00:00                   13467106              10.0
# 217898  2018-09-10 16:00:00                   13467106              13.0
# 218201  2018-09-10 17:00:00                   13467106               4.0
# 228370  2018-09-10 17:00:00                   13467106              10.0
# 239790  2018-09-17 17:00:00                   13467106              13.0
# 253415  2018-09-17 16:00:00                   13467106              13.0
# 253964  2018-09-17 16:00:00                   13467106              14.0
# 257891  2018-09-24 16:00:00                   13467106              10.0
# 257892  2018-09-24 16:00:00                   13467106              10.0
# 265824  2018-09-24 16:00:00                   13467106              10.0
# 276916  2018-09-24 17:00:00                   13467106              11.0
# 277444  2018-09-24 17:00:00                   13467106              12.0
# 281789  2018-09-24 16:00:00                   13467106              10.0
#
#            dow timewindow
# 10862   Monday     pmPeak
# 25290   Monday     pmPeak
# 30349   Monday     pmPeak
# 33318   Monday     pmPeak
# 35570   Monday     pmPeak
# 44020   Monday     pmPeak
# 61253   Monday     pmPeak
# 64828   Monday     pmPeak
# 70430   Monday     pmPeak
# 77031   Monday     pmPeak
# 113988  Monday     pmPeak
# 122954  Monday     pmPeak
# 138213  Monday     pmPeak
# 144299  Monday     pmPeak
# 146627  Monday     pmPeak
# 152044  Monday     pmPeak
# 159772  Monday     pmPeak
# 161482  Monday     pmPeak
# 170421  Monday     pmPeak
# 183507  Monday     pmPeak
# 188046  Monday     pmPeak
# 188749  Monday     pmPeak
# 202508  Monday     pmPeak
# 208302  Monday     pmPeak
# 208303  Monday     pmPeak
# 217898  Monday     pmPeak
# 218201  Monday     pmPeak
# 228370  Monday     pmPeak
# 239790  Monday     pmPeak
# 253415  Monday     pmPeak
# 253964  Monday     pmPeak
# 257891  Monday     pmPeak
# 257892  Monday     pmPeak
# 265824  Monday     pmPeak
# 276916  Monday     pmPeak
# 277444  Monday     pmPeak
# 281789  Monday     pmPeak

# %%
print(df.loc[(df['pickup_gc_intersection_id']==test_id2) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['pickup_gc_intersection_id']==test_id2) & 
       (df['dow']=='Monday') & (df['timewindow']=='pmPeak') &
       (df['pickup_ward2018']==10.0), ['pickup_datetime','pickup_gc_intersection_id','dropoff_ward2018','dow','timewindow']]
# Out:
# 6
#             pickup_datetime  pickup_gc_intersection_id  dropoff_ward2018  \
# 297451  2018-09-24 17:00:00                   13466303              13.0
# 335514  2018-09-10 17:00:00                   13466303              10.0
# 355493  2018-09-17 17:00:00                   13466303              10.0
# 385678  2018-09-24 17:00:00                   13466303              13.0
# 423080  2018-09-03 17:00:00                   13466303              11.0
# 449009  2018-09-10 17:00:00                   13466303              13.0
#
#            dow timewindow
# 297451  Monday     pmPeak
# 335514  Monday     pmPeak
# 355493  Monday     pmPeak
# 385678  Monday     pmPeak
# 423080  Monday     pmPeak
# 449009  Monday     pmPeak

# %%
thisid = 13453946

print(df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak'),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak')][['pickup_ward2018','dropoff_ward2018','dow','timewindow']]
# Out:
# 17
#         pickup_ward2018  dropoff_ward2018     dow timewindow
# 21103              10.0               1.0  Monday     amPeak
# 55108               1.0               1.0  Monday     amPeak
# 125591              7.0               1.0  Monday     amPeak
# 125592              1.0               1.0  Monday     amPeak
# 133786              5.0               1.0  Monday     amPeak
# 133882             15.0               1.0  Monday     amPeak
# 141570              7.0               1.0  Monday     amPeak
# 286280              3.0               1.0  Monday     amPeak
# 286295              1.0               1.0  Monday     amPeak
# 298822              8.0               1.0  Monday     amPeak
# 298823              8.0               1.0  Monday     amPeak
# 347543              8.0               1.0  Monday     amPeak
# 355990              1.0               1.0  Monday     amPeak
# 361525              9.0               1.0  Monday     amPeak
# 370813              8.0               1.0  Monday     amPeak
# 374278              7.0               1.0  Monday     amPeak
# 384418              7.0               1.0  Monday     amPeak

# %%
thisid = 13453946

print(df.loc[((df['pickup_gc_intersection_id']==thisid) | (df['dropoff_gc_intersection_id']==thisid)) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak'),
       'dropoff_gc_intersection_id'].count())

df.loc[((df['pickup_gc_intersection_id']==thisid) | (df['dropoff_gc_intersection_id']==thisid)) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak')][['pickup_ward2018','dropoff_ward2018','dow','timewindow']]
# Out:
# 19
#         pickup_ward2018  dropoff_ward2018     dow timewindow
# 21103              10.0               1.0  Monday     amPeak
# 55108               1.0               1.0  Monday     amPeak
# 82562               1.0               1.0  Monday     amPeak
# 125591              7.0               1.0  Monday     amPeak
# 125592              1.0               1.0  Monday     amPeak
# 133786              5.0               1.0  Monday     amPeak
# 133882             15.0               1.0  Monday     amPeak
# 141570              7.0               1.0  Monday     amPeak
# 238816              1.0              21.0  Monday     amPeak
# 286280              3.0               1.0  Monday     amPeak
# 286295              1.0               1.0  Monday     amPeak
# 298822              8.0               1.0  Monday     amPeak
# 298823              8.0               1.0  Monday     amPeak
# 347543              8.0               1.0  Monday     amPeak
# 355990              1.0               1.0  Monday     amPeak
# 361525              9.0               1.0  Monday     amPeak
# 370813              8.0               1.0  Monday     amPeak
# 374278              7.0               1.0  Monday     amPeak
# 384418              7.0               1.0  Monday     amPeak

# %% [markdown]
# # Housekeeping

# %% [markdown]
# ## 1. Round lat, lon to 4 decimal places

# %%
n=4 # number of decimals to round to

df['lat_pickup'] = df['lat_pickup'].round(decimals=n)
df['lon_pickup'] = df['lon_pickup'].round(decimals=n)

df['lat_dropoff'] = df['lat_dropoff'].round(decimals=n)
df['lon_dropoff'] = df['lon_dropoff'].round(decimals=n)

# %%
np.round(-79.60573035, decimals=n)
# Out:
# -79.6057

# %%
np.round(43.7289273, decimals=n)
# Out:
# 43.7289

# %% [markdown]
# ## 2. Filter out rows where neither pickup or dropoff wards are the ward of interest
# Make col `keep` = 1 for where pick-up or for drop-off wards are the ward of interest

# %%
# Assign a Pickup or Dropoff in column 'type'
df['keep'] = np.nan
df['latitude'] = np.nan
df['longitude'] = np.nan

df.loc[(df['pickup_ward2018']==ward) | (df['dropoff_ward2018']==ward), 'keep'] = 1

# %%
# Check
df['keep'].unique()
# Out:
# array([ 1., nan])

# %%
# Keep only rows where `keep` is not null
df = df[df['keep'].notnull()]

# %%
# Check
df['keep'].unique()
# Out:
# array([1.])

# %%
print(df.shape)
# Out:
# (166086, 17)

# %%
df.head(5)
# Out:
#        pickup_datetime     dropoff_datetime  pickup_ward2018  \
# 0  2018-09-03 00:00:00  2018-09-03 00:34:01             18.0
# 1  2018-09-03 00:00:00  2018-09-03 00:10:54             10.0
# 2  2018-09-03 00:00:00  2018-09-03 00:12:34             13.0
# 7  2018-09-03 00:00:00  2018-09-03 00:25:12             10.0
# 8  2018-09-03 00:00:00  2018-09-03 00:13:19             10.0
#
#    dropoff_ward2018  pickup_gc_intersection_id  dropoff_gc_intersection_id  \
# 0              10.0                   13447475                    13467654
# 1              13.0                   13467763                    13464030
# 2              10.0                   13464551                    13467763
# 7              23.0                   13467149                    13445567
# 8              10.0                   14621058                    13467746
#
#       dow timewindow                                        pickup_geom  \
# 0  Monday    nightII  0101000020E61000005BE2AF6670DA53C01D22DBEA93E2...
# 1  Monday    nightII  0101000020E610000051E519D30AD953C0C23B89A05BD2...
# 2  Monday    nightII  0101000020E6100000A342F6F3C6D753C0E8EE4CFEEDD4...
# 7  Monday    nightII  0101000020E6100000114B23960FD953C0EB083B20E4D2...
# 8  Monday    nightII  0101000020E6100000363D49368ED853C0D81E02B61FD2...
#
#                                         dropoff_geom  lat_pickup  lon_pickup  \
# 0  0101000020E610000013E6CE309BD953C0938FE7777DD2...     43.7701    -79.4131
# 1  0101000020E610000079E6DB3E68D853C00F3AF08356D5...     43.6434    -79.3913
# 2  0101000020E610000051E519D30AD953C0C23B89A05BD2...     43.6635    -79.3715
# 7  0101000020E610000021F13FBAB7D153C0B3D1137822E4...     43.6476    -79.3916
# 8  0101000020E610000045A22B6CE1DA53C095E3C7F86DD2...     43.6416    -79.3837
#
#    lat_dropoff  lon_dropoff  keep  latitude  longitude
# 0      43.6445     -79.4001   1.0       NaN        NaN
# 1      43.6667     -79.3814   1.0       NaN        NaN
# 2      43.6434     -79.3913   1.0       NaN        NaN
# 7      43.7823     -79.2768   1.0       NaN        NaN
# 8      43.6440     -79.4200   1.0       NaN        NaN

# %%
# Test again!! => ok
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'pickup_gc_intersection_id'].count())
df.loc[(df['dropoff_gc_intersection_id']==test_id1) & (df['dow']=='Monday') & (df['timewindow']=='amPeak'),'dropoff_gc_intersection_id'].count()
# Out:
# 62
# 13

# %%
# Test again!! => ok
print(df.loc[(df['pickup_gc_intersection_id']==test_id1) & (df['dow']==this_day) & 
             (df['pickup_ward2018']==ward) &
             (df['timewindow']==this_tod),'pickup_gc_intersection_id'].count())
# Out:
# 62

# %% [markdown]
# ## 3. Mark if row is a pickup or a dropoff
# pickup is where pickup ward == ward, dropoff is where dropoff_ward == ward
# Note that a row can contain **both** a pickup and a dropoff !!!

# %%
df['pu'] = np.nan
df['do'] = np.nan

# %%
df.loc[df['pickup_ward2018']==ward, 'pu'] = 1

# %%
df.loc[df['dropoff_ward2018']==ward, 'do'] = 1

# %%
# Check
df.loc[df['dropoff_ward2018']==ward, 
       ['dow','timewindow','pickup_datetime','dropoff_datetime',
        'lat_pickup','lon_pickup','pickup_gc_intersection_id',
        'lat_dropoff','lon_dropoff','dropoff_gc_intersection_id',
        'pickup_ward2018','dropoff_ward2018','pu','do']].head(11)
# Out:
#        dow timewindow      pickup_datetime     dropoff_datetime  lat_pickup  \
# 0   Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:34:01     43.7701
# 2   Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:12:34     43.6635
# 8   Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:13:19     43.6416
# 10  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:07:58     43.6420
# 18  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:06:50     43.6450
# 19  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:09:02     43.6394
# 20  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:10:09     43.6516
# 21  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:16:48     43.6994
# 22  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:21:32     43.7099
# 25  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:10:28     43.6672
# 26  Monday    nightII  2018-09-03 00:00:00  2018-09-03 00:07:38     43.6345
#
#     lon_pickup  pickup_gc_intersection_id  lat_dropoff  lon_dropoff  \
# 0     -79.4131                   13447475      43.6445     -79.4001
# 2     -79.3715                   13464551      43.6434     -79.3913
# 8     -79.3837                   14621058      43.6440     -79.4200
# 10    -79.3805                   13467929      43.6437     -79.3900
# 18    -79.3905                   13467570      43.6413     -79.4030
# 19    -79.3868                   13468256      43.6479     -79.4092
# 20    -79.3711                   13466440      43.6352     -79.4013
# 21    -79.4078                   13458270      43.6473     -79.3929
# 22    -79.4043                   13456603      43.6433     -79.3982
# 25    -79.3865                   20141211      43.6403     -79.3984
# 26    -79.4312                   20110527      43.6484     -79.3933
#
#     dropoff_gc_intersection_id  pickup_ward2018  dropoff_ward2018   pu   do
# 0                     13467654             18.0              10.0  NaN  1.0
# 2                     13467763             13.0              10.0  NaN  1.0
# 8                     13467746             10.0              10.0  1.0  1.0
# 10                    13467729             10.0              10.0  1.0  1.0
# 18                    14230121             10.0              10.0  1.0  1.0
# 19                    13467136             10.0              10.0  1.0  1.0
# 20                    13468720             13.0              10.0  NaN  1.0
# 21                    13467204             12.0              10.0  NaN  1.0
# 22                    13467796              8.0              10.0  NaN  1.0
# 25                    20364650             13.0              10.0  NaN  1.0
# 26                    13467040              4.0              10.0  NaN  1.0

# %%
thisid = 13453946

print(df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak'),
       'dropoff_gc_intersection_id'].count())

df.loc[(df['dropoff_gc_intersection_id']==thisid) & 
       (df['dow']=='Monday') & (df['timewindow']=='amPeak')][['pickup_ward2018','dropoff_ward2018','dow','timewindow','pu','do']]
# Out:
# 1
#        pickup_ward2018  dropoff_ward2018     dow timewindow   pu  do
# 21103             10.0               1.0  Monday     amPeak  1.0 NaN

# %% [markdown]
# ## 4a. Aggregate pickups and dropoffs

# %%
list(df)
# Out:
# ['pickup_datetime',
#  'dropoff_datetime',
#  'pickup_ward2018',
#  'dropoff_ward2018',
#  'pickup_gc_intersection_id',
#  'dropoff_gc_intersection_id',
#  'dow',
#  'timewindow',
#  'pickup_geom',
#  'dropoff_geom',
#  'lat_pickup',
#  'lon_pickup',
#  'lat_dropoff',
#  'lon_dropoff',
#  'keep',
#  'latitude',
#  'longitude',
#  'pu',
#  'do']

# %%
df_agg_pu = pd.DataFrame()

df_agg_pu = df.loc[df['pickup_ward2018']==ward].groupby(
    ['dow','timewindow','lat_pickup','lon_pickup','pickup_gc_intersection_id']
    ).size().reset_index(name='pcounts')

df_agg_pu = df_agg_pu.rename(columns={'lat_pickup': 'latitude'})
df_agg_pu = df_agg_pu.rename(columns={'lon_pickup': 'longitude'})
df_agg_pu = df_agg_pu.rename(columns={'pickup_gc_intersection_id': 'intersection_id'})

df_agg_pu.head(11)
# Out:
#        dow timewindow  latitude  longitude  intersection_id  pcounts
# 0   Monday     amPeak   43.6311   -79.4155         30021269        1
# 1   Monday     amPeak   43.6316   -79.4273         13469141        1
# 2   Monday     amPeak   43.6320   -79.4195         20229234        1
# 3   Monday     amPeak   43.6322   -79.4005         13469040        2
# 4   Monday     amPeak   43.6324   -79.3534         13468945        1
# 5   Monday     amPeak   43.6325   -79.4109         13469034       12
# 6   Monday     amPeak   43.6334   -79.3995         13468904       11
# 7   Monday     amPeak   43.6335   -79.3982         30102299        8
# 8   Monday     amPeak   43.6336   -79.4218         13468912        1
# 9   Monday     amPeak   43.6337   -79.3979         30102303       41
# 10  Monday     amPeak   43.6338   -79.4012         30096877        2

# %%
df_agg_pu.loc[(df_agg_pu['intersection_id']==13453946) & 
                 (df_agg_pu['timewindow']=='amPeak')                 
                ]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts]
# Index: []

# %%
df_agg_do = pd.DataFrame()

df_agg_do = df.loc[df['dropoff_ward2018']==ward].groupby(
    ['dow','timewindow','lat_dropoff','lon_dropoff','dropoff_gc_intersection_id']
    ).size().reset_index(name='dcounts')

df_agg_do = df_agg_do.rename(columns={'lat_dropoff': 'latitude'})
df_agg_do = df_agg_do.rename(columns={'lon_dropoff': 'longitude'})
df_agg_do = df_agg_do.rename(columns={'dropoff_gc_intersection_id': 'intersection_id'})

df_agg_do.head(11)
# Out:
#        dow timewindow  latitude  longitude  intersection_id  dcounts
# 0   Monday     amPeak   43.6309   -79.4198         13469187        1
# 1   Monday     amPeak   43.6311   -79.4155         30021269        2
# 2   Monday     amPeak   43.6312   -79.4102         13969590        2
# 3   Monday     amPeak   43.6316   -79.4273         13469141        6
# 4   Monday     amPeak   43.6318   -79.4157         30028869        2
# 5   Monday     amPeak   43.6320   -79.4195         20229234        5
# 6   Monday     amPeak   43.6322   -79.4005         13469040        1
# 7   Monday     amPeak   43.6325   -79.4109         13469034       20
# 8   Monday     amPeak   43.6327   -79.4249         13469026        2
# 9   Monday     amPeak   43.6327   -79.4222         13469023        1
# 10  Monday     amPeak   43.6329   -79.4002         30096840        3

# %%
df_agg_do.loc[(df_agg_do['intersection_id']==13453946) & 
                 (df_agg_do['timewindow']=='amPeak')                 
                ]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, dcounts]
# Index: []

# %%
print(df_agg_pu.shape)
print(df_agg_do.shape)
# Out:
# (4361, 6)
# (4289, 6)

# %% [markdown]
# ## 5. Subset this_tod

# %% [markdown]
# ### 5a. Separate pick-ups only, and drop-offs only

# %%
list(df_agg_pu)
# Out:
# ['dow', 'timewindow', 'latitude', 'longitude', 'intersection_id', 'pcounts']

# %%
print(this_tod)
df_sub_pu = df_agg_pu.loc[(df_agg_pu['timewindow']==this_tod)]

print(df_sub_pu.shape)
df_sub_pu.head(11)
# Out:
# amPeak
# (600, 6)
#        dow timewindow  latitude  longitude  intersection_id  pcounts
# 0   Monday     amPeak   43.6311   -79.4155         30021269        1
# 1   Monday     amPeak   43.6316   -79.4273         13469141        1
# 2   Monday     amPeak   43.6320   -79.4195         20229234        1
# 3   Monday     amPeak   43.6322   -79.4005         13469040        2
# 4   Monday     amPeak   43.6324   -79.3534         13468945        1
# 5   Monday     amPeak   43.6325   -79.4109         13469034       12
# 6   Monday     amPeak   43.6334   -79.3995         13468904       11
# 7   Monday     amPeak   43.6335   -79.3982         30102299        8
# 8   Monday     amPeak   43.6336   -79.4218         13468912        1
# 9   Monday     amPeak   43.6337   -79.3979         30102303       41
# 10  Monday     amPeak   43.6338   -79.4012         30096877        2

# %%
# Check for duplicate intersection_id
df_sub_pu.loc[df_sub_pu['intersection_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts]
# Index: []

# %%
df_sub_pu.loc[(df_sub_pu['intersection_id']==13453946) ]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts]
# Index: []

# %%
list(df_agg_do)
# Out:
# ['dow', 'timewindow', 'latitude', 'longitude', 'intersection_id', 'dcounts']

# %%
print(this_tod)
df_sub_do = df_agg_do.loc[(df_agg_do['timewindow']==this_tod)]

print(df_sub_do.shape)
df_sub_do.head(11)
# Out:
# amPeak
# (567, 6)
#        dow timewindow  latitude  longitude  intersection_id  dcounts
# 0   Monday     amPeak   43.6309   -79.4198         13469187        1
# 1   Monday     amPeak   43.6311   -79.4155         30021269        2
# 2   Monday     amPeak   43.6312   -79.4102         13969590        2
# 3   Monday     amPeak   43.6316   -79.4273         13469141        6
# 4   Monday     amPeak   43.6318   -79.4157         30028869        2
# 5   Monday     amPeak   43.6320   -79.4195         20229234        5
# 6   Monday     amPeak   43.6322   -79.4005         13469040        1
# 7   Monday     amPeak   43.6325   -79.4109         13469034       20
# 8   Monday     amPeak   43.6327   -79.4249         13469026        2
# 9   Monday     amPeak   43.6327   -79.4222         13469023        1
# 10  Monday     amPeak   43.6329   -79.4002         30096840        3

# %%
# Check for duplicate intersection_id
df_sub_do.loc[df_sub_do['intersection_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, dcounts]
# Index: []

# %%
df_sub_do.loc[(df_sub_do['intersection_id']==13453946) ]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, dcounts]
# Index: []

# %% [markdown]
# ### 5b. Stack pickups on top of dropoffs

# %%
# Add empty columns to allow stacking

df_sub_pu=df_sub_pu.assign(dcounts=0)
df_sub_do=df_sub_do.assign(pcounts=0)

# %%
# stack
print(df_sub_pu.shape)
print(df_sub_do.shape)

df_merge=pd.concat([df_sub_pu, df_sub_do],sort=False)

print(df_merge.shape)
df_merge.head(11)
# Out:
# (600, 7)
# (567, 7)
# (1167, 7)
#        dow timewindow  latitude  longitude  intersection_id  pcounts  dcounts
# 0   Monday     amPeak   43.6311   -79.4155         30021269        1        0
# 1   Monday     amPeak   43.6316   -79.4273         13469141        1        0
# 2   Monday     amPeak   43.6320   -79.4195         20229234        1        0
# 3   Monday     amPeak   43.6322   -79.4005         13469040        2        0
# 4   Monday     amPeak   43.6324   -79.3534         13468945        1        0
# 5   Monday     amPeak   43.6325   -79.4109         13469034       12        0
# 6   Monday     amPeak   43.6334   -79.3995         13468904       11        0
# 7   Monday     amPeak   43.6335   -79.3982         30102299        8        0
# 8   Monday     amPeak   43.6336   -79.4218         13468912        1        0
# 9   Monday     amPeak   43.6337   -79.3979         30102303       41        0
# 10  Monday     amPeak   43.6338   -79.4012         30096877        2        0

# %%
# Check
this_id=13453946
df_merge.loc[df_merge['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts, dcounts]
# Index: []

# %% [markdown]
# ### 5c. Group on common `intersection_id`

# %%
df_merge.loc[df_merge['intersection_id']==13453946]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts, dcounts]
# Index: []

# %%
df_merge.loc[df_merge['intersection_id']==30092304]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts, dcounts]
# Index: []

# %%
df_merge_gr=pd.DataFrame()

df_merge_gr=df_merge.groupby(['intersection_id','latitude','longitude'],as_index=False).sum()

print(df_merge_gr.shape)
df_merge_gr.head(11)
# Out:
# (667, 5)
#     intersection_id  latitude  longitude  pcounts  dcounts
# 0          13465870   43.6554   -79.3852       16       18
# 1          13465901   43.6552   -79.3861       29       26
# 2          13465978   43.6547   -79.3841        5        2
# 3          13466018   43.6545   -79.3849       45       22
# 4          13466030   43.6545   -79.3904       12       18
# 5          13466048   43.6543   -79.3832       40       42
# 6          13466064   43.6543   -79.3915       11       80
# 7          13466190   43.6534   -79.3864        3       53
# 8          13466234   43.6531   -79.3876        9       52
# 9          13466250   43.6530   -79.3826        5       33
# 10         13466303   43.6528   -79.3934        3        0

# %%
# Check
this_id=13453946
df_merge_gr.loc[df_merge_gr['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [intersection_id, latitude, longitude, pcounts, dcounts]
# Index: []

# %% [markdown]
# ## 6. Make the dataframes for each layer!

# %% [markdown]
# ### a. PUDO layer from `df_merge_gr`

# %%
df_pudo_layer = pd.DataFrame()

# %%
df_pudo_layer = df_merge_gr.loc[(df_merge_gr['pcounts']>0) & (df_merge_gr['dcounts']>0)]

# %%
print(df_pudo_layer.shape)
# Out:
# (500, 5)

# %%
# Check
this_id=13453946
df_pudo_layer.loc[df_pudo_layer['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [intersection_id, latitude, longitude, pcounts, dcounts]
# Index: []

# %% [markdown]
# ### a. PU layer and DO layer from `df_merge`

# %%
df_pu_layer = pd.DataFrame()
df_do_layer = pd.DataFrame()

# %%
df_pu_layer = df_merge.loc[(df_merge['pcounts']>0) & (df_merge['dcounts']==0)]
df_do_layer = df_merge.loc[(df_merge['pcounts']==0) & (df_merge['dcounts']>0)]

# %%
# Check
this_id=13453946
df_pu_layer.loc[df_pu_layer['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts, dcounts]
# Index: []

# %%
# Check
this_id=13453946
df_do_layer.loc[df_do_layer['intersection_id']==this_id]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts, dcounts]
# Index: []

# %% [markdown]
# # Histograms of counts

# %%
print('w' +repr(ward), this_day, this_tod)
# Out:
# w10 Monday amPeak

# %%
# Check for duplicate intersection_id
df_pu_layer.loc[df_pu_layer['intersection_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [dow, timewindow, latitude, longitude, intersection_id, pcounts, dcounts]
# Index: []

# %%
print(df_pu_layer.shape)
print(df_pu_layer['pcounts'].max())
print(df_pu_layer['pcounts'].min())
df_pu_layer.head(5)
# Out:
# (600, 7)
# 184
# 1
#       dow timewindow  latitude  longitude  intersection_id  pcounts  dcounts
# 0  Monday     amPeak   43.6311   -79.4155         30021269        1        0
# 1  Monday     amPeak   43.6316   -79.4273         13469141        1        0
# 2  Monday     amPeak   43.6320   -79.4195         20229234        1        0
# 3  Monday     amPeak   43.6322   -79.4005         13469040        2        0
# 4  Monday     amPeak   43.6324   -79.3534         13468945        1        0

# %%
df_pu_layer.hist(column='pcounts',bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8791f3b240>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

n = 20
print(df_pu_layer['pcounts'].max())
print('bin width: ' + repr(df_pu_layer['pcounts'].max()/n))

ax = df_pu_layer.hist(column='pcounts', bins=n, grid=True, figsize=(9,8), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("pcounts", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Bin counts", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
# Out:
# 184
# bin width: 9.2

# %%
df=
# Out:
#   File "<ipython-input-60-02c2a1c0215a>", line 1
#     df=
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Save to geojson

# %%
print('w' +repr(ward), this_day, this_tod)

# %%
df_do_layer.head(5)

# %%
this_id=13453946
df_pudo_layer.loc[df_pudo_layer['intersection_id']==this_id]

# %%
df_pudo_layer.sort_values('dcounts',ascending=False).head(9)

# %% [markdown]
# ## Apply cut-off filter
# Only counts > `c` will be saved.

# %%
c = 9 # cut-off

# %%
df_do_layer.loc[(df_do_layer['dcounts']>=c)]

# %%
this_id=13453946
df_pu_layer.loc[ (df_pu_layer['intersection_id']==thisid)]

# %%
this_id=13453946
df_do_layer.loc[ (df_do_layer['intersection_id']==thisid)]

# %%
this_id=13453946
df_pudo_layer.loc[ ((df_pudo_layer['pcounts']+df_pudo_layer['dcounts']) >= c) &
                  (df_pudo_layer['intersection_id'] == thisid)
                                                    ]

# %%
geojson_pu_layer = df_to_geojson(df_pu_layer.loc[(df_pu_layer['pcounts']>=c)], ['pcounts'])

# %%
geojson_do_layer = df_to_geojson(df_do_layer.loc[(df_do_layer['dcounts']>=c)], ['dcounts'])

# %%
geojson_pudo_layer = df_to_geojson(df_pudo_layer.loc[(df_pudo_layer['pcounts']>=c) &
                                                     (df_pudo_layer['dcounts']>=c)
                                                    ], ['pcounts','dcounts'])

# %% [markdown]
# # Write geojson to file

# %% [markdown]
# ## Aggregated points

# %%
print('w' +repr(ward), this_day, this_tod)

# %%
mydir = '../../../Documents/PROJECTS/VFH/COT_PAGE/INTERIM_DATA/INDIVIDUAL_GEOJSONS/'
# mydir = '/home/nangini/Documents/PROJECTS/BDITTO/VFH/DATA_STORY/DATA/INDIVIDUAL_GEOJSONS/'


output_filename = mydir + 'w' + repr(ward) + '_092018_' + this_day + '_' + this_tod + '_pu_cutoff.geojson'

with open(output_filename, 'w') as output_file:
    output_file.write('')
    json.dump(geojson_pu_layer, output_file, indent=2)

# %%
output_filename = mydir + 'w' + repr(ward) + '_092018_' + this_day + '_' + this_tod + '_do_cutoff.geojson'

with open(output_filename, 'w') as output_file:
    output_file.write('')
    json.dump(geojson_do_layer, output_file, indent=2)

# %%
output_filename = mydir + 'w' + repr(ward) + '_092018_' + this_day + '_' + this_tod + '_pudo_cutoff.geojson'

with open(output_filename, 'w') as output_file:
    output_file.write('')
    json.dump(geojson_pudo_layer, output_file, indent=2)

# %% [markdown]
# `
# $ ls -lh ~/Documents/PROJECTS/VFH/COT_PAGE/INTERIM_DATA/INDIVIDUAL_GEOJSONS/
# total 216K
# -rw-r--r-- 1 test test 109K Dec  9 11:23 w1_092018_Monday_pmPeak_do_agg.geojson
# -rw-r--r-- 1 test test 104K Dec  9 11:23 w1_092018_Monday_pmPeak_pu_agg.geojson
# `

# %% [markdown]
# `
# $ ls -lh src/geojson/
# -rw-r--r-- 1 test test 328K Dec  4 15:46 w1_092018_Monday_amPeak_agg.geojson
# -rw-r--r-- 1 test test 753K Dec  4 13:51 w1_092018_Monday_amPeak.geojson
# `
